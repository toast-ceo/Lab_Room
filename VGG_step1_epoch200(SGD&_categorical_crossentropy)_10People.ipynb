# %% [markdown]
# <a href="https://colab.research.google.com/github/toast-ceo/Lab_Room/blob/main/VGG_step1_epoch200(SGD%26_categorical_crossentropy)_10People.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# vgg 19 훈련

from google.colab import drive
drive.mount('face550_step')
import tensorflow as tf
import numpy as np
import keras
import cv2

from keras.applications.vgg19 import VGG19
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Flatten
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
# Out:
# Mounted at face550_step

# %%
numberOfClass = 30
pictureWeightHeightSize = 224

train_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        '/content/face550_step/MyDrive/face550_step/step1_train/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),
        batch_size=numberOfClass,
        class_mode='categorical')

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
        '/content/face550_step/MyDrive/face550_step/step10_test/',
        target_size=(pictureWeightHeightSize, pictureWeightHeightSize),    
        batch_size=numberOfClass,
        class_mode='categorical')
# Out:
# Found 100 images belonging to 10 classes.
# Found 20 images belonging to 10 classes.

# %%
input_layer = tf.keras.layers.Input(shape=(224, 224, 3))

vgg_block01 = tf.keras.layers.Conv2D(64 , (3,3), padding= 'SAME', activation="relu")(input_layer)
vgg_block01 = tf.keras.layers.Conv2D(64 , (3,3), padding= 'SAME', activation="relu")(vgg_block01)
vgg_block01 = tf.keras.layers.MaxPool2D((2,2))(vgg_block01)


vgg_block02 = tf.keras.layers.Conv2D(128 , (3,3), padding= 'SAME', activation="relu")(vgg_block01)
vgg_block02 = tf.keras.layers.Conv2D(128, (3,3), padding= 'SAME', activation="relu")(vgg_block02)
vgg_block02 = tf.keras.layers.MaxPool2D((2,2))(vgg_block02)


vgg_block03 = tf.keras.layers.Conv2D(256, (3,3), padding= 'SAME', activation="relu")(vgg_block02)
vgg_block03 = tf.keras.layers.Conv2D(256, (3,3), padding= 'SAME', activation="relu")(vgg_block03)
vgg_block03 = tf.keras.layers.Conv2D(256, (3,3), padding= 'SAME', activation="relu")(vgg_block03)
vgg_block03 = tf.keras.layers.MaxPool2D((2,2))(vgg_block03)

vgg_block04 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block03)
vgg_block04 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block04)
vgg_block04 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block04)
vgg_block04 = tf.keras.layers.MaxPool2D((2,2))(vgg_block04)

vgg_block05 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block04)
vgg_block05 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block05)
vgg_block05 = tf.keras.layers.Conv2D(512, (3,3), padding= 'SAME', activation="relu")(vgg_block05)
vgg_block05 = tf.keras.layers.MaxPool2D((2,2))(vgg_block05)

# %%
flatten = tf.keras.layers.Flatten()(vgg_block05)
dense01 = tf.keras.layers.Dense(512, activation='relu')(flatten)
output = tf.keras.layers.Dense(10, activation='softmax')(dense01)

# %%
model = tf.keras.models.Model(input_layer, output)

# %%
model.compile(optimizer='SGD', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 512)               12845568
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 27,565,386
# Trainable params: 27,565,386
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_generator, epochs=200, validation_data=test_generator)
# Out:
# Epoch 1/200
# 4/4 [==============================] - 211s 62s/step - loss: 2.3024 - accuracy: 0.1100 - val_loss: 2.3026 - val_accuracy: 0.2000
# Epoch 2/200
# 4/4 [==============================] - 199s 60s/step - loss: 2.3015 - accuracy: 0.1500 - val_loss: 2.3025 - val_accuracy: 0.1000
# Epoch 3/200
# 4/4 [==============================] - 202s 61s/step - loss: 2.3005 - accuracy: 0.2200 - val_loss: 2.3025 - val_accuracy: 0.2000
# Epoch 4/200
# 4/4 [==============================] - 199s 60s/step - loss: 2.2997 - accuracy: 0.3800 - val_loss: 2.3024 - val_accuracy: 0.2000
# Epoch 5/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2990 - accuracy: 0.3500 - val_loss: 2.3024 - val_accuracy: 0.1000
# Epoch 6/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2985 - accuracy: 0.3500 - val_loss: 2.3023 - val_accuracy: 0.1000
# Epoch 7/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2979 - accuracy: 0.2900 - val_loss: 2.3023 - val_accuracy: 0.2000
# Epoch 8/200
# 4/4 [==============================] - 200s 60s/step - loss: 2.2980 - accuracy: 0.3300 - val_loss: 2.3022 - val_accuracy: 0.1000
# Epoch 9/200
# 4/4 [==============================] - 200s 47s/step - loss: 2.2972 - accuracy: 0.3300 - val_loss: 2.3022 - val_accuracy: 0.2000
# Epoch 10/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2968 - accuracy: 0.2500 - val_loss: 2.3021 - val_accuracy: 0.1000
# Epoch 11/200
# 4/4 [==============================] - 202s 48s/step - loss: 2.2958 - accuracy: 0.5100 - val_loss: 2.3021 - val_accuracy: 0.1000
# Epoch 12/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2954 - accuracy: 0.4400 - val_loss: 2.3020 - val_accuracy: 0.1000
# Epoch 13/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2951 - accuracy: 0.1800 - val_loss: 2.3019 - val_accuracy: 0.1000
# Epoch 14/200
# 4/4 [==============================] - 199s 48s/step - loss: 2.2942 - accuracy: 0.1200 - val_loss: 2.3018 - val_accuracy: 0.1000
# Epoch 15/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2937 - accuracy: 0.1000 - val_loss: 2.3017 - val_accuracy: 0.1000
# Epoch 16/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2929 - accuracy: 0.3400 - val_loss: 2.3016 - val_accuracy: 0.1000
# Epoch 17/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2921 - accuracy: 0.3400 - val_loss: 2.3015 - val_accuracy: 0.2000
# Epoch 18/200
# 4/4 [==============================] - 197s 59s/step - loss: 2.2915 - accuracy: 0.6600 - val_loss: 2.3013 - val_accuracy: 0.2000
# Epoch 19/200
# 4/4 [==============================] - 199s 48s/step - loss: 2.2899 - accuracy: 0.7300 - val_loss: 2.3011 - val_accuracy: 0.1000
# Epoch 20/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2895 - accuracy: 0.2900 - val_loss: 2.3009 - val_accuracy: 0.1000
# Epoch 21/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2879 - accuracy: 0.3200 - val_loss: 2.3008 - val_accuracy: 0.1000
# Epoch 22/200
# 4/4 [==============================] - 199s 48s/step - loss: 2.2864 - accuracy: 0.5200 - val_loss: 2.3005 - val_accuracy: 0.1000
# Epoch 23/200
# 4/4 [==============================] - 199s 48s/step - loss: 2.2847 - accuracy: 0.5900 - val_loss: 2.3004 - val_accuracy: 0.2000
# Epoch 24/200
# 4/4 [==============================] - 203s 49s/step - loss: 2.2834 - accuracy: 0.5800 - val_loss: 2.2999 - val_accuracy: 0.2000
# Epoch 25/200
# 4/4 [==============================] - 201s 48s/step - loss: 2.2808 - accuracy: 0.6600 - val_loss: 2.2997 - val_accuracy: 0.2000
# Epoch 26/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.2780 - accuracy: 0.6200 - val_loss: 2.2993 - val_accuracy: 0.2000
# Epoch 27/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2761 - accuracy: 0.6100 - val_loss: 2.2989 - val_accuracy: 0.2000
# Epoch 28/200
# 4/4 [==============================] - 198s 60s/step - loss: 2.2727 - accuracy: 0.6000 - val_loss: 2.2985 - val_accuracy: 0.2000
# Epoch 29/200
# 4/4 [==============================] - 200s 48s/step - loss: 2.2681 - accuracy: 0.6600 - val_loss: 2.2977 - val_accuracy: 0.1000
# Epoch 30/200
# 4/4 [==============================] - 199s 60s/step - loss: 2.2628 - accuracy: 0.6000 - val_loss: 2.2968 - val_accuracy: 0.2000
# Epoch 31/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2579 - accuracy: 0.6700 - val_loss: 2.2962 - val_accuracy: 0.1000
# Epoch 32/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.2515 - accuracy: 0.7700 - val_loss: 2.2945 - val_accuracy: 0.2000
# Epoch 33/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2413 - accuracy: 0.7200 - val_loss: 2.2925 - val_accuracy: 0.2000
# Epoch 34/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.2284 - accuracy: 0.7100 - val_loss: 2.2910 - val_accuracy: 0.2000
# Epoch 35/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.2039 - accuracy: 0.5400 - val_loss: 2.2860 - val_accuracy: 0.2000
# Epoch 36/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.1646 - accuracy: 0.5100 - val_loss: 2.2816 - val_accuracy: 0.2000
# Epoch 37/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.0967 - accuracy: 0.4500 - val_loss: 2.2925 - val_accuracy: 0.2000
# Epoch 38/200
# 4/4 [==============================] - 197s 47s/step - loss: 2.0166 - accuracy: 0.4300 - val_loss: 2.3667 - val_accuracy: 0.1000
# Epoch 39/200
# 4/4 [==============================] - 199s 48s/step - loss: 2.0734 - accuracy: 0.3300 - val_loss: 2.4064 - val_accuracy: 0.1000
# Epoch 40/200
# 4/4 [==============================] - 199s 47s/step - loss: 1.8238 - accuracy: 0.3800 - val_loss: 2.5429 - val_accuracy: 0.1000
# Epoch 41/200
# 4/4 [==============================] - 198s 60s/step - loss: 1.6445 - accuracy: 0.5200 - val_loss: 2.4410 - val_accuracy: 0.2000
# Epoch 42/200
# 4/4 [==============================] - 197s 59s/step - loss: 2.7948 - accuracy: 0.3500 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 43/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2553 - accuracy: 0.5300 - val_loss: 2.3002 - val_accuracy: 0.1000
# Epoch 44/200
# 4/4 [==============================] - 205s 49s/step - loss: 2.2195 - accuracy: 0.5100 - val_loss: 2.2967 - val_accuracy: 0.1000
# Epoch 45/200
# 4/4 [==============================] - 200s 60s/step - loss: 2.1351 - accuracy: 0.5000 - val_loss: 2.3006 - val_accuracy: 0.1000
# Epoch 46/200
# 4/4 [==============================] - 203s 61s/step - loss: 1.9650 - accuracy: 0.4600 - val_loss: 2.2677 - val_accuracy: 0.1000
# Epoch 47/200
# 4/4 [==============================] - 199s 47s/step - loss: 1.6863 - accuracy: 0.6000 - val_loss: 2.2367 - val_accuracy: 0.1000
# Epoch 48/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.1421 - accuracy: 0.5000 - val_loss: 2.2713 - val_accuracy: 0.2000
# Epoch 49/200
# 4/4 [==============================] - 198s 60s/step - loss: 2.0777 - accuracy: 0.5000 - val_loss: 2.2221 - val_accuracy: 0.2000
# Epoch 50/200
# 4/4 [==============================] - 197s 47s/step - loss: 1.5554 - accuracy: 0.5900 - val_loss: 3.6971 - val_accuracy: 0.1000
# Epoch 51/200
# 4/4 [==============================] - 198s 47s/step - loss: 0.8751 - accuracy: 0.7200 - val_loss: 3.2618 - val_accuracy: 0.0000e+00
# Epoch 52/200
# 4/4 [==============================] - 197s 59s/step - loss: 0.7660 - accuracy: 0.8300 - val_loss: 2.9256 - val_accuracy: 0.2000
# Epoch 53/200
# 4/4 [==============================] - 200s 60s/step - loss: 0.0834 - accuracy: 0.9700 - val_loss: 5.6945 - val_accuracy: 0.2000
# Epoch 54/200
# 4/4 [==============================] - 197s 59s/step - loss: 3.3913 - accuracy: 0.2800 - val_loss: 2.3039 - val_accuracy: 0.1000
# Epoch 55/200
# 4/4 [==============================] - 196s 47s/step - loss: 2.2945 - accuracy: 0.1300 - val_loss: 2.3034 - val_accuracy: 0.1000
# Epoch 56/200
# 4/4 [==============================] - 198s 47s/step - loss: 2.2875 - accuracy: 0.2000 - val_loss: 2.3018 - val_accuracy: 0.1000
# Epoch 57/200
# 4/4 [==============================] - 199s 47s/step - loss: 2.2742 - accuracy: 0.3100 - val_loss: 2.2992 - val_accuracy: 0.1000
# Epoch 58/200
# 4/4 [==============================] - 200s 60s/step - loss: 2.2506 - accuracy: 0.4600 - val_loss: 2.2958 - val_accuracy: 0.1000
# Epoch 59/200
# 4/4 [==============================] - 202s 48s/step - loss: 2.2112 - accuracy: 0.6700 - val_loss: 2.2910 - val_accuracy: 0.1000
# Epoch 60/200
# 4/4 [==============================] - 201s 48s/step - loss: 2.1298 - accuracy: 0.7000 - val_loss: 2.2871 - val_accuracy: 0.2000
# Epoch 61/200
# 4/4 [==============================] - 198s 60s/step - loss: 1.8001 - accuracy: 0.6200 - val_loss: 2.3563 - val_accuracy: 0.2000
# Epoch 62/200
# 4/4 [==============================] - 200s 48s/step - loss: 1.2025 - accuracy: 0.6300 - val_loss: 2.9748 - val_accuracy: 0.2500
# Epoch 63/200
# 4/4 [==============================] - 200s 48s/step - loss: 1.5022 - accuracy: 0.8400 - val_loss: 2.7334 - val_accuracy: 0.1000
# Epoch 64/200
# 4/4 [==============================] - 196s 59s/step - loss: 0.6548 - accuracy: 0.8600 - val_loss: 2.6470 - val_accuracy: 0.1000
# Epoch 65/200
# 4/4 [==============================] - 200s 48s/step - loss: 0.5669 - accuracy: 0.8700 - val_loss: 3.3694 - val_accuracy: 0.1000
# Epoch 66/200
# 4/4 [==============================] - 199s 47s/step - loss: 0.0386 - accuracy: 1.0000 - val_loss: 4.0414 - val_accuracy: 0.1000
# Epoch 67/200
# 4/4 [==============================] - 199s 60s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 4.3782 - val_accuracy: 0.1000
# Epoch 68/200
# 4/4 [==============================] - 198s 47s/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 4.6452 - val_accuracy: 0.1000
# Epoch 69/200
# 4/4 [==============================] - 198s 60s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 4.8528 - val_accuracy: 0.1000
# Epoch 70/200
# 4/4 [==============================] - 197s 47s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 5.0134 - val_accuracy: 0.1000
# Epoch 71/200
# 4/4 [==============================] - 198s 47s/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 5.1560 - val_accuracy: 0.1000
# Epoch 72/200
# 4/4 [==============================] - 198s 47s/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 5.2800 - val_accuracy: 0.1000
# Epoch 73/200
# 4/4 [==============================] - 197s 47s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 5.3798 - val_accuracy: 0.1000
# Epoch 74/200
# 4/4 [==============================] - 200s 59s/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 5.4717 - val_accuracy: 0.1000
# Epoch 75/200
# 4/4 [==============================] - 199s 60s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 5.5659 - val_accuracy: 0.1000
# Epoch 76/200
# 4/4 [==============================] - 198s 60s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 5.6438 - val_accuracy: 0.1000
# Epoch 77/200
# 4/4 [==============================] - 194s 46s/step - loss: 9.9140e-04 - accuracy: 1.0000 - val_loss: 5.7163 - val_accuracy: 0.1000
# Epoch 78/200
# 4/4 [==============================] - 197s 60s/step - loss: 9.0056e-04 - accuracy: 1.0000 - val_loss: 5.7826 - val_accuracy: 0.1000
# Epoch 79/200
# 4/4 [==============================] - 194s 46s/step - loss: 8.1708e-04 - accuracy: 1.0000 - val_loss: 5.8573 - val_accuracy: 0.1000
# Epoch 80/200
# 4/4 [==============================] - 192s 46s/step - loss: 7.4872e-04 - accuracy: 1.0000 - val_loss: 5.9213 - val_accuracy: 0.1000
# Epoch 81/200
# 4/4 [==============================] - 193s 58s/step - loss: 6.9483e-04 - accuracy: 1.0000 - val_loss: 5.9698 - val_accuracy: 0.1000
# Epoch 82/200
# 4/4 [==============================] - 194s 58s/step - loss: 6.2396e-04 - accuracy: 1.0000 - val_loss: 6.0155 - val_accuracy: 0.1000
# Epoch 83/200
# 4/4 [==============================] - 195s 47s/step - loss: 5.8413e-04 - accuracy: 1.0000 - val_loss: 6.0647 - val_accuracy: 0.1000
# Epoch 84/200
# 4/4 [==============================] - 194s 58s/step - loss: 5.4452e-04 - accuracy: 1.0000 - val_loss: 6.1133 - val_accuracy: 0.1000
# Epoch 85/200
# 4/4 [==============================] - 194s 46s/step - loss: 5.0359e-04 - accuracy: 1.0000 - val_loss: 6.1603 - val_accuracy: 0.1000
# Epoch 86/200
# 4/4 [==============================] - 195s 46s/step - loss: 4.8072e-04 - accuracy: 1.0000 - val_loss: 6.2017 - val_accuracy: 0.1000
# Epoch 87/200
# 4/4 [==============================] - 196s 47s/step - loss: 4.5063e-04 - accuracy: 1.0000 - val_loss: 6.2383 - val_accuracy: 0.1000
# Epoch 88/200
# 4/4 [==============================] - 198s 47s/step - loss: 4.1934e-04 - accuracy: 1.0000 - val_loss: 6.2769 - val_accuracy: 0.1000
# Epoch 89/200
# 4/4 [==============================] - 194s 46s/step - loss: 4.0091e-04 - accuracy: 1.0000 - val_loss: 6.3154 - val_accuracy: 0.1000
# Epoch 90/200
# 4/4 [==============================] - 194s 46s/step - loss: 3.8033e-04 - accuracy: 1.0000 - val_loss: 6.3476 - val_accuracy: 0.1000
# Epoch 91/200
# 4/4 [==============================] - 195s 47s/step - loss: 3.6115e-04 - accuracy: 1.0000 - val_loss: 6.3792 - val_accuracy: 0.1000
# Epoch 92/200
# 4/4 [==============================] - 197s 47s/step - loss: 3.4385e-04 - accuracy: 1.0000 - val_loss: 6.4092 - val_accuracy: 0.1000
# Epoch 93/200
# 4/4 [==============================] - 196s 59s/step - loss: 3.3043e-04 - accuracy: 1.0000 - val_loss: 6.4382 - val_accuracy: 0.1000
# Epoch 94/200
# 4/4 [==============================] - 195s 46s/step - loss: 3.1552e-04 - accuracy: 1.0000 - val_loss: 6.4698 - val_accuracy: 0.1000
# Epoch 95/200
# 4/4 [==============================] - 196s 47s/step - loss: 3.0612e-04 - accuracy: 1.0000 - val_loss: 6.5016 - val_accuracy: 0.1000
# Epoch 96/200
# 4/4 [==============================] - 194s 46s/step - loss: 2.9072e-04 - accuracy: 1.0000 - val_loss: 6.5291 - val_accuracy: 0.1000
# Epoch 97/200
# 4/4 [==============================] - 195s 46s/step - loss: 2.7874e-04 - accuracy: 1.0000 - val_loss: 6.5556 - val_accuracy: 0.1000
# Epoch 98/200
# 4/4 [==============================] - 195s 59s/step - loss: 2.7341e-04 - accuracy: 1.0000 - val_loss: 6.5848 - val_accuracy: 0.1000
# Epoch 99/200
# 4/4 [==============================] - 197s 47s/step - loss: 2.5968e-04 - accuracy: 1.0000 - val_loss: 6.6078 - val_accuracy: 0.1000
# Epoch 100/200
# 4/4 [==============================] - 195s 46s/step - loss: 2.4803e-04 - accuracy: 1.0000 - val_loss: 6.6327 - val_accuracy: 0.1000
# Epoch 101/200
# 4/4 [==============================] - 196s 47s/step - loss: 2.4054e-04 - accuracy: 1.0000 - val_loss: 6.6576 - val_accuracy: 0.1000
# Epoch 102/200
# 4/4 [==============================] - 196s 47s/step - loss: 2.3166e-04 - accuracy: 1.0000 - val_loss: 6.6826 - val_accuracy: 0.1000
# Epoch 103/200
# 4/4 [==============================] - 195s 47s/step - loss: 2.2401e-04 - accuracy: 1.0000 - val_loss: 6.7086 - val_accuracy: 0.1000
# Epoch 104/200
# 4/4 [==============================] - 201s 47s/step - loss: 2.1596e-04 - accuracy: 1.0000 - val_loss: 6.7307 - val_accuracy: 0.1000
# Epoch 105/200
# 4/4 [==============================] - 195s 46s/step - loss: 2.0990e-04 - accuracy: 1.0000 - val_loss: 6.7508 - val_accuracy: 0.1000
# Epoch 106/200
# 4/4 [==============================] - 193s 58s/step - loss: 2.0566e-04 - accuracy: 1.0000 - val_loss: 6.7753 - val_accuracy: 0.1000
# Epoch 107/200
# 4/4 [==============================] - 193s 46s/step - loss: 1.9749e-04 - accuracy: 1.0000 - val_loss: 6.7955 - val_accuracy: 0.1000
# Epoch 108/200
# 4/4 [==============================] - 193s 46s/step - loss: 1.9116e-04 - accuracy: 1.0000 - val_loss: 6.8136 - val_accuracy: 0.1000
# Epoch 109/200
# 4/4 [==============================] - 198s 47s/step - loss: 1.8518e-04 - accuracy: 1.0000 - val_loss: 6.8328 - val_accuracy: 0.1000
# Epoch 110/200
# 4/4 [==============================] - 195s 47s/step - loss: 1.7985e-04 - accuracy: 1.0000 - val_loss: 6.8520 - val_accuracy: 0.1000
# Epoch 111/200
# 4/4 [==============================] - 198s 47s/step - loss: 1.7509e-04 - accuracy: 1.0000 - val_loss: 6.8701 - val_accuracy: 0.1000
# Epoch 112/200
# 4/4 [==============================] - 202s 48s/step - loss: 1.7090e-04 - accuracy: 1.0000 - val_loss: 6.8899 - val_accuracy: 0.1000
# Epoch 113/200
# 4/4 [==============================] - 201s 48s/step - loss: 1.6527e-04 - accuracy: 1.0000 - val_loss: 6.9102 - val_accuracy: 0.1000
# Epoch 114/200
# 4/4 [==============================] - 201s 61s/step - loss: 1.6069e-04 - accuracy: 1.0000 - val_loss: 6.9284 - val_accuracy: 0.1000
# Epoch 115/200
# 4/4 [==============================] - 202s 48s/step - loss: 1.5712e-04 - accuracy: 1.0000 - val_loss: 6.9460 - val_accuracy: 0.1000
# Epoch 116/200
# 4/4 [==============================] - 202s 48s/step - loss: 1.5177e-04 - accuracy: 1.0000 - val_loss: 6.9640 - val_accuracy: 0.1000
# Epoch 117/200
# 4/4 [==============================] - 200s 48s/step - loss: 1.4838e-04 - accuracy: 1.0000 - val_loss: 6.9799 - val_accuracy: 0.1000
# Epoch 118/200
# 4/4 [==============================] - 193s 46s/step - loss: 1.4546e-04 - accuracy: 1.0000 - val_loss: 6.9963 - val_accuracy: 0.1000
# Epoch 119/200
# 4/4 [==============================] - 195s 59s/step - loss: 1.4241e-04 - accuracy: 1.0000 - val_loss: 7.0118 - val_accuracy: 0.1000
# Epoch 120/200
# 4/4 [==============================] - 193s 46s/step - loss: 1.3873e-04 - accuracy: 1.0000 - val_loss: 7.0265 - val_accuracy: 0.1000
# Epoch 121/200
# 4/4 [==============================] - 198s 47s/step - loss: 1.3571e-04 - accuracy: 1.0000 - val_loss: 7.0411 - val_accuracy: 0.1000
# Epoch 122/200
# 4/4 [==============================] - 201s 48s/step - loss: 1.3416e-04 - accuracy: 1.0000 - val_loss: 7.0554 - val_accuracy: 0.1000
# Epoch 123/200
# 4/4 [==============================] - 200s 48s/step - loss: 1.3089e-04 - accuracy: 1.0000 - val_loss: 7.0705 - val_accuracy: 0.1000
# Epoch 124/200
# 4/4 [==============================] - 201s 48s/step - loss: 1.2731e-04 - accuracy: 1.0000 - val_loss: 7.0843 - val_accuracy: 0.1000
# Epoch 125/200

# %%
print("-- Evaluate --")
scores = model.evaluate(test_generator)
print("%s: %.2f%%" %(model.metrics_names[1], scores[1]*100))

# %%
print("-- Predict --")
output = model.predict(test_generator)
np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print(test_generator.class_indices)
print(output)

# %%
for i in range(0, 10):
  print("Result:", i+1)
  print(output[i])
  print("\n")
